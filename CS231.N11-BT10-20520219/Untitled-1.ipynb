# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = plt.imread('Ho.jpg')
img2 = plt.imread('Meo.jpg')

# %%
h,w,c = img1.shape

# %%
img2 = cv.resize(img2,(w,h))

# %%
plt.imshow(img1)
plt.imshow(img2)

# %%
# Loop f from 0 to 72
for f in range (0,72):
